# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:\\doc\\csi500.csv",parse_dates=[0],index_col=0)

# %%
df.head()
# Out:
#                 price   leverage
# date
# 2020-12-31  6367.1149  3288.1495
# 2020-12-30  6269.2484  3283.2693
# 2020-12-29  6199.8523  3275.2013
# 2020-12-28  6244.4818  3286.8931
# 2020-12-25  6278.4981  3266.3224

# %%
sns.scatterplot(x="leverage",y="price",data=df)

# %%
df.plot(grid=True)
